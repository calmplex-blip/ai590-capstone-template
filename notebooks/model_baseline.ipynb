# %% [markdown]
# # Milestone 2 - Model and Architecture Baseline
# State the question, authorized inputs, method, acceptance rule, evidence, and limitation before adding code.

# %%
from pathlib import Path
import json
RANDOM_STATE = 590
